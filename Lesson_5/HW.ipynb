# %% [markdown]
# 1. В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной филтьтрации?

# %% [markdown]
# В дополнение к таблице взаимодействия пользователей и товаров, в гибридных системах, подаются фичи самих пользователей и товаров.

# %% [markdown]
# 2. Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы

# %% [markdown]
# - При поиске работы имеется множество фичей соискателя, на которые можно опираться. Множество фичей вакансий.
# - При работе магазина электроники имеется множество фичей (параметров аппаратуры), опираясь на которые, при появление нового товара, можно рекомендовать новый товар похожий на старый товар.

# %% [markdown]
# 3. Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/
#
# Нам интересна именно рекомендательная система, раздел "Производительность системы" можно пропустить
# Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах? Какие проблемы могут возникнуть при выводе такой модели в продакшен?

# %% [markdown]
# Принцип работы поиска ххру:
#     1. Происходит фильтрация признаков, которая начинается с фильтрации тех фичей, которые разработчики обнаружили вручную.
#     2. Отфильтровывают еще больше количество признаков.
#     3. Ансамбль двух моделей ранжирования:
#         линейную: используется для того, чтобы быстро и с малой ресурсоёмкостью отделять подходящие вакансии от неподходящих и грубо ранжировать неподходящие;
#         XGBoost: используется, чтобы более точно ранжировать подходящие.
#
# При этом вакансии, похожие на резюме, и вакансии, на которые владельцу резюме хочется откликнуться, — далеко не одно и то же". Тоесть отслеживались вакансии на которые пользователь нажимал.
#
# На семинаре мы изучали модели LightFM, которая придерживается следующих соображений:
# 1. Модель должна уметь узнавать представления пользователей и предметов из данных взаимодействия: если предметы, описанные как "бальное платье" и "юбка-карандаш", последовательно нравятся пользователям, модель должна узнать, что бальные платья похожи на юбки-карандаши.
# 2. Модель должна быть способна вычислять рекомендации для новых элементов и пользователей.

# %% [markdown]
# На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
#
#     1) Какой датасет используют авторы?
#     2) Что используют в качестве признаков?
#     3) С какими моделями сравнивают LightFM? Опишите их основные идеи кратко

# %% [markdown]
# 1) Какой датасет используют авторы?
#
# - В первом эксперименте используется хорошо известный набор данных MovieLens 10M dataset 3 в сочетании с набором тегов Getname.
# - Второй набор данных состоит из вопросов и ответов, размещенных на CrossValidated 4, части более крупной сети совместных сайтов вопросов и ответов Фондовой биржи, которая фокусируется на статистике и машинном обучении.

# %% [markdown]
# 2) Что используют в качестве признаков?
#
#     MovieLens - Список жанров и список тэгов фильма, рейтинг точности тега к фильму, оценки пользователей.
#     CrossValidated - Вопросы и ответы пользователей

# %% [markdown]
# 3) С какими моделями сравнивают LightFM? Опишите их основные идеи кратко
#
# - MF - матричная модель User х Item с функцией сигмойды
# - LSI-LR - логистическая регрессияю. Основывается на факторизации матрицы контента.
# - LSI-UP - гибридная модель, которая представляет профили пользователей, как линейную комбинацию предметов по векторам, затем применяет LSI к получившейся матрице, чтобы получить скрытые представления пользователей и элементов.
